# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from random import randint
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Crystal_structure.csv')

# %%
data.count()
# Out:
# Compound             5329
# A                    5329
# B                    5329
# In literature        5329
# v(A)                 5329
# v(B)                 5329
# r(AXII)(Å)           5329
# r(AVI)(Å)            5329
# r(BVI)(Å)            5329
# EN(A)                5329
# EN(B)                5329
# l(A-O)(Å)            5329
# l(B-O)(Å)            5329
# ΔENR                 5329
# tG                   5329
# τ                    5329
# μ                    5329
# Lowest distortion    5329
# dtype: int64

# %%
data.head()
# Out:
#   Compound   A   B  In literature v(A) v(B)  r(AXII)(Å)  r(AVI)(Å)  r(BVI)(Å)  \
# 0    Ac2O3  Ac  Ac          False    0    0        1.12       1.12       1.12
# 1   AcAgO3  Ac  Ag          False    0    0        1.12       1.12       0.95
# 2   AcAlO3  Ac  Al          False    0    0        1.12       1.12       0.54
# 3   AcAsO3  Ac  As          False    0    0        1.12       1.12       0.52
# 4   AcAuO3  Ac  Au          False    0    0        1.12       1.12       0.93
#
#    EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)      ΔENR        tG  τ         μ  \
# 0    1.1   1.10        0.0   0.000000 -3.248000  0.707107  -  0.800000
# 1    1.1   1.93        0.0   2.488353 -2.565071  0.758259  -  0.678571
# 2    1.1   1.61        0.0   1.892894 -1.846714  0.918510  -  0.385714
# 3    1.1   2.18        0.0   1.932227 -1.577429  0.928078  -  0.371429
# 4    1.1   2.54        0.0   2.313698 -2.279786  0.764768  -  0.664286
#
#   Lowest distortion
# 0             cubic
# 1      orthorhombic
# 2             cubic
# 3      orthorhombic
# 4      orthorhombic

# %%
#data cleaning, dropping 'In literature' and 'compound' column

# %%
data = data.drop(["In literature"], axis=1)
data.columns
# Out:
# Index(['Compound', 'A', 'B', 'v(A)', 'v(B)', 'r(AXII)(Å)', 'r(AVI)(Å)',
#        'r(BVI)(Å)', 'EN(A)', 'EN(B)', 'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG',
#        'τ', 'μ', 'Lowest distortion'],
#       dtype='object')

# %%
data = data.drop(["Compound"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'v(A)', 'v(B)', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)',
#        'EN(A)', 'EN(B)', 'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'τ', 'μ',
#        'Lowest distortion'],
#       dtype='object')

# %%
(data=='-').any()
# Out:
# A                    False
# B                    False
# v(A)                  True
# v(B)                  True
# r(AXII)(Å)           False
# r(AVI)(Å)            False
# r(BVI)(Å)            False
# EN(A)                False
# EN(B)                False
# l(A-O)(Å)            False
# l(B-O)(Å)            False
# ΔENR                 False
# tG                   False
# τ                     True
# μ                    False
# Lowest distortion     True
# dtype: bool

# %%
print(data["v(A)"].unique())
print(data["v(B)"].unique())
# Out:
# ['0' '-' '1' '3' '2' '4' '5']
# ['0' '-' '5' '3' '4' '2' '1']

# %%
(data["v(A)"] == "-").sum(), (data["v(B)"] == "-").sum()
# Out:
# (1881, 1881)

# %%
((data["v(A)"] == "-").sum() and (data["v(B)"] == "-").sum()).sum()
# Out:
# 1881

# %%
valency_a_one_hot = pd.get_dummies(data['v(A)'], prefix="v(A)=", prefix_sep="")
valency_b_one_hot = pd.get_dummies(data['v(B)'], prefix="v(B)=", prefix_sep="")
data = pd.concat([data, valency_a_one_hot, valency_b_one_hot], axis=1)

# %%
data = data.drop(["v(A)"], axis=1)
data = data.drop(["v(B)"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)', 'EN(A)', 'EN(B)',
#        'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'τ', 'μ', 'Lowest distortion',
#        'v(A)=-', 'v(A)=0', 'v(A)=1', 'v(A)=2', 'v(A)=3', 'v(A)=4', 'v(A)=5',
#        'v(B)=-', 'v(B)=0', 'v(B)=1', 'v(B)=2', 'v(B)=3', 'v(B)=4', 'v(B)=5'],
#       dtype='object')

# %%
len(data["τ"].unique())
# Out:
# 1608

# %%
data = data.drop(["τ"], axis=1)
data.columns
# Out:
# Index(['A', 'B', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)', 'EN(A)', 'EN(B)',
#        'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR', 'tG', 'μ', 'Lowest distortion',
#        'v(A)=-', 'v(A)=0', 'v(A)=1', 'v(A)=2', 'v(A)=3', 'v(A)=4', 'v(A)=5',
#        'v(B)=-', 'v(B)=0', 'v(B)=1', 'v(B)=2', 'v(B)=3', 'v(B)=4', 'v(B)=5'],
#       dtype='object')

# %%
(data["Lowest distortion"] == "-").sum()
# Out:
# 53

# %%
a_one_hot = pd.get_dummies(data['A'], prefix="A=", prefix_sep="")
b_one_hot = pd.get_dummies(data['B'], prefix="B=", prefix_sep="")
data = pd.concat([data, a_one_hot, b_one_hot], axis=1)

# %%
data.columns
# Out:
# Index(['A', 'B', 'r(AXII)(Å)', 'r(AVI)(Å)', 'r(BVI)(Å)', 'EN(A)', 'EN(B)',
#        'l(A-O)(Å)', 'l(B-O)(Å)', 'ΔENR',
#        ...
#        'B=Ti', 'B=Tl', 'B=Tm', 'B=U', 'B=V', 'B=W', 'B=Y', 'B=Yb', 'B=Zn',
#        'B=Zr'],
#       dtype='object', length=173)

# %%
data = data.drop(["A"], axis=1)
data = data.drop(["B"], axis=1)

# %%
unknown_data = data[data["Lowest distortion"] == "-"]
data = data.drop(data[data["Lowest distortion"] == "-"].index)

# %%
unknown_data
# Out:
#       r(AXII)(Å)  r(AVI)(Å)  r(BVI)(Å)  EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)  \
# 666         1.34       1.00       1.00   1.00   1.00   2.648078   2.318139
# 817         1.24       0.94       1.67   1.12   0.79   2.577786   3.009747
# 890         0.90       0.63       1.67   1.88   0.79   2.233563   3.009747
# 963         0.57       0.58       1.67   1.66   0.79   2.258107   3.009747
# 1034        1.88       1.67       0.63   0.79   1.88   3.300176   1.930311
# 1035        1.88       1.67       0.58   0.79   1.66   3.300176   1.960053
# 3007 -4.107893  0.541271  1.192857  ...    0     0     0    0    0    0    0
# 3040 -2.327643  0.745157  0.592857  ...    0     0     0    0    0    0    0
# 3059 -2.332143  0.738534  0.607143  ...    0     0     0    1    0    0    0
# 3299 -4.546250  0.594246  1.192857  ...    0     0     0    0    0    0    0
# 3431 -3.042286  0.662211  0.800000  ...    0     0     0    0    0    0    0
# 3440 -2.836571  0.695322  0.714286  ...    0     0     0    0    0    0    0
# 3443 -1.794857  0.822055  0.450000  ...    0     0     0    0    0    0    0
# 3445 -4.248571  0.543574  1.192857  ...    0     0     0    0    0    0    0
# 3446 -1.888000  0.802294  0.485714  ...    0     0     0    0    0    0    0
# 3458 -1.685143  0.822055  0.450000  ...    0     0     0    0    0    0    0
# 3460 -2.862286  0.686737  0.735714  ...    0     0     0    0    0    0    0
# 3470 -2.433143  0.738395  0.614286  ...    0     0     0    0    0    0    0
# 3481 -1.617714  0.830235  0.435714  ...    0     0     0    0    0    0    0
# 4321 -4.428786  0.575820  1.192857  ...    0     0     0    0    0    0    0
# 4759 -4.351643  0.564303  1.192857  ...    0     0     0    0    0    0    0
# 4905 -3.812679  0.488295  1.192857  ...    0     0     0    0    0    0    0
#
#       B=Yb  B=Zn  B=Zr
# 666      0     0     0
# 817      0     0     0
# 890      0     0     0
# 963      0     0     0
# 1034     0     0     0
# 1035     0     0     0
# 1055     0     0     0
# 1060     0     0     0
# 1182     0     0     0
# 1413     0     0     0
# 1418     0     0     0
# 1440     0     0     0
# 1456     0     0     0
# 1545     0     0     0
# 1693     0     0     0
# 2156     0     0     0
# 2277     0     0     0
# 2423     0     0     0
# 2667     0     0     0
# 2715     0     0     0
# 2781     0     0     0
# 2786     0     0     0
# 2788     0     0     0
# 2800     0     0     0
# 2802     0     0     0
# 2805     0     0     0
# 2812     0     0     0
# 2813     0     0     0
# 2814     0     0     0
# 2822     0     0     0
# 2827     0     0     0
# 2834     0     0     0
# 2836     0     0     0
# 2840     0     0     0
# 2861     0     0     0
# 2886     0     0     0
# 2929     0     0     0
# 3007     0     0     0
# 3040     0     0     0
# 3059     0     0     0
# 3299     0     0     0
# 3431     0     0     0
# 3440     0     0     0
# 3443     0     0     0
# 3445     0     0     0
# 3446     0     0     0
# 3458     0     0     0
# 3460     0     0     0
# 3470     0     0     0
# 3481     0     0     0
# 4321     0     0     0
# 4759     0     0     0
# 4905     0     0     0
#
# [53 rows x 171 columns]

# %%
class_names = data["Lowest distortion"].unique()
class_names
# Out:
# array(['cubic', 'orthorhombic', 'rhombohedral', 'tetragonal'],
#       dtype=object)

# %%
data["Lowest distortion"] = data["Lowest distortion"].astype('category')
data["Lowest distortion"] = data["Lowest distortion"].cat.codes

# %%
len(data), len(unknown_data)
# Out:
# (5276, 53)

# %%
features = data.drop(labels=["Lowest distortion"], axis=1)
target = data["Lowest distortion"]

# %%
target
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5324    0
# 5325    0
# 5326    1
# 5327    0
# 5328    0
# Name: Lowest distortion, Length: 5276, dtype: int8

# %%
SEED = 0
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=SEED)

# %%
data
# Out:
#       r(AXII)(Å)  r(AVI)(Å)  r(BVI)(Å)  EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)  \
# 0           1.12       1.12       1.12   1.10   1.10    0.00000   0.000000
# 1           1.12       1.12       0.95   1.10   1.93    0.00000   2.488353
# 2           1.12       1.12       0.54   1.10   1.61    0.00000   1.892894
# 3           1.12       1.12       0.52   1.10   2.18    0.00000   1.932227
# 4           1.12       1.12       0.93   1.10   2.54    0.00000   2.313698
# ...          ...        ...        ...    ...    ...        ...        ...
# 5324        0.89       0.72       0.62   1.33   2.36    2.38342   1.745600
# 5325        0.89       0.72       0.90   1.33   1.22    2.38342   2.235124
# 5326        0.89       0.72       0.95   1.33   1.10    2.38342   2.223981
# 5327        0.89       0.72       0.74   1.33   1.65    2.38342   2.096141
# 5328        0.89       0.72       0.72   1.33   1.33    2.38342   2.043778
#
#           ΔENR        tG         μ  ...  B=Ti  B=Tl  B=Tm  B=U  B=V  B=W  B=Y  \
# 0    -3.248000  0.707107  0.800000  ...     0     0     0    0    0    0    0
# 1    -2.565071  0.758259  0.678571  ...     0     0     0    0    0    0    0
# 2    -1.846714  0.918510  0.385714  ...     0     0     0    0    0    0    0
# 3    -1.577429  0.928078  0.371429  ...     0     0     0    0    0    0    0
# 4    -2.279786  0.764768  0.664286  ...     0     0     0    0    0    0    0
# ...        ...       ...       ...  ...   ...   ...   ...  ...  ...  ...  ...
# 5324 -1.572214  0.801621  0.442857  ...     0     0     0    0    0    1    0
# 5325 -2.489571  0.704032  0.642857  ...     0     0     0    0    0    0    1
# 5326 -2.626821  0.689053  0.678571  ...     0     0     0    0    0    0    0
# 5327 -2.035750  0.756670  0.528571  ...     0     0     0    0    0    0    0
# 5328 -2.097821  0.763809  0.514286  ...     0     0     0    0    0    0    0
#
#       B=Yb  B=Zn  B=Zr
# 0        0     0     0
# 1        0     0     0
# 2        0     0     0
# 3        0     0     0
# 4        0     0     0
# ...    ...   ...   ...
# 5324     0     0     0
# 5325     0     0     0
# 5326     1     0     0
# 5327     0     1     0
# 5328     0     0     1
#
# [5276 rows x 171 columns]

# %%
forest = RandomForestClassifier(n_estimators=1000, random_state=SEED, verbose=1)
forest = forest.fit(X_train, y_train)
forest.verbose = 0
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:   12.2s finished

# %%
forest.score(X_test, y_test)
# Out:
# 0.7926136363636364

# %%
forest1 = RandomForestClassifier(n_estimators=1000, random_state=SEED)
forest1 = forest.fit(X_train, y_train)

# %%
forest.score(X_test, y_test)
# Out:
# 0.7926136363636364

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision = DecisionTreeClassifier(random_state=SEED)

# %%
decision.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
decision.score(X_test,y_test)
# Out:
# 0.7357954545454546

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(X_train,y_train)
# Out:
# C:\Users\Shantharama\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_model.score(X_test,y_test)
# Out:
# 0.6998106060606061

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC(random_state = 0)

# %%
model_svc.fit(X_train,y_train)
# Out:
# SVC(random_state=0)

# %%
model_svc.score(X_test,y_test)
# Out:
# 0.6865530303030303
